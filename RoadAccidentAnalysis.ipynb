# %%
#importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#loading the csv
RAA=pd.read_csv('UK_Accident.csv')

# %%
#Showing the first 10 elements in the dataset
RAA.head(10)
# Out:
#    Unnamed: 0 Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0           0  200501BS00001               525680.0                178240.0
# 1           1  200501BS00002               524170.0                181650.0
# 2           2  200501BS00003               524520.0                182240.0
# 3           3  200501BS00004               526900.0                177530.0
# 4           4  200501BS00005               528060.0                179040.0
# 5           5  200501BS00006               524770.0                181160.0
# 6           6  200501BS00007               524220.0                180830.0
# 7           7  200501BS00009               525890.0                179710.0
# 8           8  200501BS00010               527350.0                177650.0
# 9           9  200501BS00011               524550.0                180810.0
#
#    Longitude   Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# ...

# %%
#showing the last 10 elements in the dataset
RAA.tail(10)
# Out:
#          Unnamed: 0 Accident_Index  Location_Easting_OSGR  \
# 1504140      464687       2.01E+12               312649.0
# 1504141      464688       2.01E+12               316306.0
# 1504142      464689       2.01E+12               311115.0
# 1504143      464690       2.01E+12               328339.0
# 1504144      464691       2.01E+12               307298.0
# 1504145      464692       2.01E+12               310037.0
# 1504146      464693       2.01E+12               321509.0
# 1504147      464694       2.01E+12               321337.0
# 1504148      464695       2.01E+12               323869.0
# 1504149      464696       2.01E+12               314072.0
#
#          Location_Northing_OSGR  Longitude   Latitude  Police_Force  \
# 1504140                583604.0  -3.371842  55.139088            98
# 1504141                568290.0  -3.309988  55.002141            98
# 1504142                574365.0  -3.393009  55.055816            98
# ...

# %%
#DATATYPES
RAA.dtypes
# Out:
# Unnamed: 0                                       int64
# Accident_Index                                  object
# Location_Easting_OSGR                          float64
# Location_Northing_OSGR                         float64
# Longitude                                      float64
# Latitude                                       float64
# Police_Force                                     int64
# Accident_Severity                                int64
# Number_of_Vehicles                               int64
# Number_of_Casualties                             int64
# Date                                            object
# Day_of_Week                                      int64
# Time                                            object
# Local_Authority_(District)                       int64
# Local_Authority_(Highway)                       object
# 1st_Road_Class                                   int64
# 1st_Road_Number                                  int64
# ...

# %%
#showing descriptive statistics
RAA.describe()
# Out:
#          Unnamed: 0  Location_Easting_OSGR  Location_Northing_OSGR  \
# count  1.504150e+06           1.504049e+06            1.504150e+06
# mean   2.530433e+05           4.396214e+05            3.001382e+05
# std    1.489162e+05           9.511616e+04            1.610218e+05
# min    0.000000e+00           6.495000e+04            0.000000e+00
# 25%    1.253452e+05           3.750600e+05            1.782600e+05
# 50%    2.506910e+05           4.399600e+05            2.688000e+05
# 75%    3.760370e+05           5.230600e+05            3.981500e+05
# max    5.700100e+05           6.553700e+05            1.208800e+06
#
#           Longitude      Latitude  Police_Force  Accident_Severity  \
# count  1.504049e+06  1.504150e+06  1.504150e+06       1.504150e+06
# mean  -1.436625e+00  5.258587e+01  3.020536e+01       2.838190e+00
# std    1.398078e+00  1.512524e+00  2.551603e+01       4.018423e-01
# min   -7.516225e+00  0.000000e+00  1.000000e+00       1.000000e+00
# ...

# %%
#description about the dataset
RAA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1504150 entries, 0 to 1504149
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Unnamed: 0                                   1504150 non-null  int64
#  1   Accident_Index                               1504150 non-null  object
#  2   Location_Easting_OSGR                        1504049 non-null  float64
#  3   Location_Northing_OSGR                       1504150 non-null  float64
#  4   Longitude                                    1504049 non-null  float64
#  5   Latitude                                     1504150 non-null  float64
#  6   Police_Force                                 1504150 non-null  int64
#  7   Accident_Severity                            1504150 non-null  int64
#  8   Number_of_Vehicles                           1504150 non-null  int64
# ...

# %%
#checking for missing values in the dataset
RAA.isnull().sum()
# Out:
# Unnamed: 0                                          0
# Accident_Index                                      0
# Location_Easting_OSGR                             101
# Location_Northing_OSGR                              0
# Longitude                                         101
# Latitude                                            0
# Police_Force                                        0
# Accident_Severity                                   0
# Number_of_Vehicles                                  0
# Number_of_Casualties                                0
# Date                                                0
# Day_of_Week                                         0
# Time                                              117
# Local_Authority_(District)                          0
# Local_Authority_(Highway)                           0
# 1st_Road_Class                                      0
# 1st_Road_Number                                     0
# ...

# %%
#total number of rows and columns in a dataset
RAA.shape
# Out:
# (1504150, 33)

# %%
#total number of items in the dataset
RAA.size
# Out:
# 49636950

# %%
#counting the number of items in each column
RAA.count()
# Out:
# Unnamed: 0                                     1504150
# Accident_Index                                 1504150
# Location_Easting_OSGR                          1504049
# Location_Northing_OSGR                         1504150
# Longitude                                      1504049
# Latitude                                       1504150
# Police_Force                                   1504150
# Accident_Severity                              1504150
# Number_of_Vehicles                             1504150
# Number_of_Casualties                           1504150
# Date                                           1504150
# Day_of_Week                                    1504150
# Time                                           1504033
# Local_Authority_(District)                     1504150
# Local_Authority_(Highway)                      1504150
# 1st_Road_Class                                 1504150
# 1st_Road_Number                                1504150
# ...

# %%
#filling null values using forward and backward fill
RAA=RAA.bfill().ffill()
Raa=RAA.to_csv('UK_Accident1.csv')

# %%
RAA.isnull().sum()
# Out:
# Unnamed: 0                                     0
# Accident_Index                                 0
# Location_Easting_OSGR                          0
# Location_Northing_OSGR                         0
# Longitude                                      0
# Latitude                                       0
# Police_Force                                   0
# Accident_Severity                              0
# Number_of_Vehicles                             0
# Number_of_Casualties                           0
# Date                                           0
# Day_of_Week                                    0
# Time                                           0
# Local_Authority_(District)                     0
# Local_Authority_(Highway)                      0
# 1st_Road_Class                                 0
# 1st_Road_Number                                0
# Road_Type                                      0
# Speed_limit                                    0
# ...

# %%
#Grouping
#showing the minimum values
RAA.groupby('Date').min()
# Out:
#             Unnamed: 0 Accident_Index  Location_Easting_OSGR  \
# Date
# 01/01/2005         742      2.01E+106               136200.0
# 01/01/2006      201478       2.01E+12               178530.0
# 01/01/2007      388614       2.01E+12               222000.0
# 01/01/2009           0    2.00903E+12               180130.0
# 01/01/2010      164246    2.01003E+12               169710.0
# ...                ...            ...                    ...
# 31/12/2010      164234    2.01007E+12               202390.0
# 31/12/2011      320894    2.01103E+12               178640.0
# 31/12/2012         605       2.01E+12               195460.0
# 31/12/2013      180373       2.01E+12               147192.0
# 31/12/2014      319082       2.01E+12               122300.0
#
#             Location_Northing_OSGR  Longitude   Latitude  Police_Force  \
# Date
# 01/01/2005                 51370.0  -6.511986  50.351450             1
# 01/01/2006                 34500.0  -5.102759  50.168989             1
# ...
